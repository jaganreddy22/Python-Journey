# %% [markdown]
# #I/O statements

# %% [markdown]
# ##input()->it reads the input from the terminal

# %%
a=input('enter a nummber ')
print(a)
# Out:
# 20

# %% [markdown]
# ##type casting for input by using eval

# %% [markdown]
# ###int

# %%
a=eval(input('enter a coll:'))
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %% [markdown]
# ###float

# %%
a=float(input('enter a coll:'))
print(a)
print(type(a))
# Out:
# 20.0
# <class 'float'>

# %% [markdown]
# ###complex

# %%
a=eval(input('enter a coll:'))
print(a)
print(type(a))
# Out:
# (3+4j)
# <class 'complex'>

# %% [markdown]
# ###bool

# %%
a=eval(input('enter a coll:'))
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# ###string

# %%
a=eval(input('enter a coll:'))
print(a)
print(type(a))
# Out:
# ramu
# <class 'str'>

# %% [markdown]
# ###list

# %%
a=eval(input('enter a coll:'))
print(a)
print(type(a))
# Out:
# [10, 20, 30]
# <class 'list'>

# %% [markdown]
# ###tuple

# %%
a=eval(input('enter a coll:'))
print(a)
print(type(a))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %% [markdown]
# ###set

# %%
a=eval(input('enter a coll:'))
print(a)
print(type(a))
# Out:
# {10, 20, 30}
# <class 'set'>

# %% [markdown]
# ###dict

# %%
a=eval(input('enter a coll:'))
print(a)
print(type(a))
# Out:
# {'a': 10, 'b': 20}
# <class 'dict'>
