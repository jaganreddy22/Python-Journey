# %% [markdown]
# #Control Statements

# %% [markdown]
# ##condition Satements

# %% [markdown]
# ###if statements programs

# %%
#special symbol or not
char=input('enter the char: ')
if not ('0'<=char<='9' or 'A'<=char<='Z' or 'a'<=char<='z'):
    print(f'{char} it is a special symbol')
# Out:
# * it is a special symbol

# %%
#given number is divisible by 3 and 5
n=int(input())
if n%3==0 and n%5==0:
    print(f'{n} is divisble by 3 and 5')
# Out:
# 60 is divisble by 3 and 5

# %%
#give word is key word
import keyword
s=input()
if s in keyword.kwlist:
    print(f'{s} is key word')

# %%
#give number is divisble by 2 and 6 if yes convert to complex
n=int(input("enter a number "))
if n%2==0 and n%6==0:
    print(f'{n} is divisible 2 and 6 so it covert into {complex(n)}')
# Out:
# 18 is divisible 2 and 6 so it covert into (18+0j)

# %%
#to check last digit end with 5 store in list
n=int(input('Enter a number: '))
arr=[]
last=n%10
if last==5:
    print(f'{n} consist end letter {last}')
    arr.append(last)
    print(arr)
# Out:
# 45 consist end letter 5
# [5]

# %%
#given number is odd store it in tuple
n=int(input())
if n%2!=0:
    res=(n,)
    print(f'{n} is odd so it store in tuple as {res}')
# Out:
# 3421 is odd so it store in tuple as (3421,)

# %% [markdown]
# ###3rd day

# %%
#write a program to check mid element if yes print the mid element
word=input('enter a word: ')
if len(word)%2!=0:
    print(word[len(word)//2])
# Out:
# t

# %%
#write a program to check mid element if yes print the mid element to word last
word=input('enter a word: ')
if len(word)%2!=0:
    mid=len(word)//2
    print('original name is ',word)
    print('after mid element coverted to last is',word[:mid]+word[mid+1:]+word[mid])
# Out:
# original name is  sitha
# after mid element coverted to last is sihat

# %%
word=input('enter a name: ')
length=len(word)
if length%2!=0:
    dic={word:length}
    print(dic)
# Out:
# {'wonderr': 7}

# %%
#check both vales are pointing to same address
a=[1,2,34]
b=a

if a is b:
    print('same memory')
# Out:
# same memory

# %%
#check any one number or bith number sum is 10 print square of number
a=int(input('enter a number1: '))
b=int(input('enter a number2: '))
if a==10 or b==10 or a+b==10:
    print(a**2,b**2)
# Out:
# 49 9

# %%
#write a program to given character is vowel if yes print the next letter
char=input('enter a char: ')
if char in 'AEIOUaeiou':
    print(char)
    print(chr(ord(char)+1))
# Out:
# a
# b

# %%
#to check given data is multivalue or not
a =eval(input())
if type(a) in [list,set,tuple,dict,str]:
    print("Multivalue")

# %%
#to check given key is present in 
a=eval(input('enter dictionary '))
keyy=eval(input("enter the key: "))
if keyy in a:
    print("key exists")
print(a)
print(keyy)
# Out:
# key exists
# {10: 20, 30: 40}
# 10

# %%
#update key in dict 
a=eval(input('enter dictionary '))
keyy=eval(input("enter the key: "))
val=eval(input('enter the update value: '))
print('before dic ',a)
if keyy in a:
    a[keyy]=val
print('after dic ',a)
# Out:
# before dic  {10: 20, 30: 40}
# after dic  {10: 100, 30: 40}

# %%
#remove  key in dict 
a=eval(input('enter dictionary '))
keyy=eval(input("enter the remove key: "))
print('before dic ',a)
if keyy in a:
    a.pop(keyy)
print('after dic ',a)
# Out:
# before dic  {10: 20, 30: 40}
# after dic  {30: 40}

# %% [markdown]
# ## if else:-

# %%
#wap to check len string is odd add hi for starting string else remove fir and last character in the string
a=eval(input('enter a word: '))
if len(a)%2!=0:
    print('Hi '+a)
else:
    print(a[1:len(a)-1])
# Out:
# am

# %%
#to check first character is special symbol and the length is oddif yes display mid element or reverse the string
word=eval(input('enter the word: '))
if not('0'<=word<='9' or 'A'<=word<='Z' or 'a'<=word<='z') and len(word)%2!=0:
    mid=len(word)//2
    print('give word is ',word)
    print('middle of the letetr in the word is ',word[mid])
else:
    print(word[::-1])
# Out:
# give word is  !ramu
# middle of the letetr in the word is  a

# %%
#to check leap year or not
year=eval(input('enter the year: '))
if (year%400==0)or(year%4==0 and year%100!=0):
    print(f'{year} it is leap year')
else:
    print(f'{year} it is not leap year')
# Out:
# 1300 it is not leap year

# %%
#to check whether the fir key is int
dic=eval(input('enter the dic:'))
fir=list(dic)[0]
if type(fir)==int:
    print('the first key is int',dic)
else:
    print('the first key is not int',dic)
# Out:
# the first key is not int {'a': 10}

# %%
#to check last character is special symbol if yes reverse the string expect last value else print as it is
word=eval(input('enter the word: '))
last=word[len(word)-1]
if not('0'<=last<='9' or 'A'<=last<='Z' or 'a'<=last<='z'):
    mid=len(word)//2
    print('give word is ',word)
    print('reverse of word is ',word[::-1])

else:
    print(word)
# Out:
# ramu

# %%
tup=eval(input('enter two values of tuples: '))
if type(tup[0])==type(tup[1]):
    print('homo')
else:
    print('hetero')
# Out:
# homo

# %%
a=int(input('enter a number: '))
if a>99 and a<=999:
    print('it is 3 digit number')
else:
    print('it is not a 3 digit number')
# Out:
# it is 3 digit number

# %%
s=eval(input('enter the string: '))
if s == s[::-1]:
    print('the original string is ',s)
    print(f'the revesre of given string is {s[::-1]} so it is palindrome')
else:
    print(f'{s}')
# Out:
# the original string is  madam
# the revesre of given string is madam so it is palindrome

# %%
s=eval(input('enter the string: '))
if len(s)==5:
    print(s,'it consist of 5 characters')
else:
    print("it does not have exactly 5 characters")
# Out:
# hello it consist of 5 characters

# %%
s=eval(input('enter the string: '))
pas=123
if s==pas:
    print('correct password')
else:
    print('not correct password')
# Out:
# correct password

# %%
bal=5000
withdraw=int(input('enter the withdraw amount: '))
print(f'{bal} availabale amount before transaction')
if bal>=withdraw:
    print(f'{bal-withdraw} the available balance,withdraw amount is {withdraw}')
else:
    print(f'insufficient balance the withdraw amount is {withdraw}')
# Out:
# 5000 availabale amount before transaction
# insufficient balance the withdraw amount is 7000
